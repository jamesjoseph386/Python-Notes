# %% [markdown]
#  Python Data Structures
#  Using data structures, you may arrange your data in a way that makes it more accessible
#  under different circumstances. The foundation of any programming language is its data
#  structures, which serve as the building blocks for programs. Python, in contrast to other
#  programming languages, makes it easier to understand the foundations of various data
#  structures.
#  Lists
#  Python Lists are just like the arrays, declared in other languages which is an ordered
#  collection of data. It is very flexible as the items in a list do not need to be of the same type.

# %%
 #Creating Python List
 List = [1, 2,  3, "apple", 2.3, "xyz"]
 print("\n A simple Python List, L: ")
 print(List)
# Out:
#  A simple Python List, L:
# [1, 2, 3, 'apple', 2.3, 'xyz']

# %%
 # Creating a multidimensional list,that is, nesting a list inside a li
 # (By Nesting a list inside a List) 
List2 = [['Apple', 'Mango'], ['Tomato','Potato','Chillies'],['Rice','Pickle']]
 print("\nMulti-Dimensional List in Python, Grocery: ") 
print(List2)
# Out:
# Multi-Dimensional List in Python, Grocery:
# [['Apple', 'Mango'], ['Tomato', 'Potato', 'Chillies'], ['Rice', 'Pickle']]

# %% [markdown]
# #### Different operations in a list
#  accesing an element from the list of a particular index
#  accesing an element from the list using negative indexing
#  deleting an element from the list
#  slicing the list

# %%
 # accessing a element from the list using index number 
print("Accessing element from the list") 
print(List[0])  
print(List[2])
print(List2[2])
print(List2[0])
print(List2[0][1])
# Out:
# Accessing element from the list
# 1
# 3
# ['Rice', 'Pickle']
# ['Apple', 'Mango']
# Mango

# %%
# accessing a element using negative indexing 
print("Accessing element using negative indexing") 
List3 = ["a", "b",  3, "chocolates", 2.3, "juice"]     
print(List3)
 # print the second element of list using negative indexing
print(List3[-5]) 
# print the third last element of list  
print(List3[-3])
# Out:
# Accessing element using negative indexing
# ['a', 'b', 3, 'chocolates', 2.3, 'juice']
# b
# chocolates

# %%
#print fourth element of the list
List4 = [['Raj', 'Angel'], ['Apple','Kiwi','Banana'],['Maths','Computer Science'],[1,2,3]]
print(List4[3])
# Out:
# [1, 2, 3]

# %%
 #print fourth element of the list using negative indexing

# %%
# Initialize list
List7 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print("Original List:\n", List7)
#Syntax for slicing is : List[ Initial : End : IndexJump ]
print("\nSliced Lists: ")
# Display sliced list
print(List7[3:9:2])
# Display sliced list
print(List7[::2])
# Display sliced list
print(List7[::])
# Out:
# Original List:
#  [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# Sliced Lists:
# [4, 6, 8]
# [1, 3, 5, 7, 9]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Initialize list
Lst = [50, 70, 30, 20, 90, 10, 50]
# Display sliced list using negative indexing
print(Lst[-7::5])
print(Lst[8:1:-2])
# Out:
# [50, 10]
# [50, 90, 30]

# %%
# Initialize list
List = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Show original list
print("Original List:\n", List)
print("\nSliced Lists: ")
# Creating new List
newList = List[:3]+List[7:]
# Display sliced list
print(newList)
# Changing existing List
List = List[::2]+List[1::2]
# Display sliced list
print(List)
# Out:
# Original List:
#  [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# Sliced Lists:
# [1, 2, 3, 8, 9]
# [1, 3, 5, 7, 9, 2, 4, 6, 8]

# %% [markdown]
# The list data type has some more methods.
# Here are all of the methods of list objects:
#
# $\bullet$ list.append(x) Add an item to the end of the list. Equivalent to a[len(a):] = [x].
#
# $\bullet$ list.extend(iterable) Extend the list by appending all the items from the iterable.
#  Equivalent to a[len(a):] = iterable.
#
# $\bullet$ list.insert(i, x) Insert an item at a given position. The first argument is the index of the element before which to insert, so a.insert(0, x) inserts at the front of the list, and a.insert(len(a), x) is equivalent to a.append(x).
#
# $\bullet$ list.remove(x) Remove the first item from the list whose value is equal to x. It raises a ValueError if there is no such item.
#
# $\bullet$ list.pop(i) Remove the item at the given position in the list, and return it. If no index isspecified, a.pop() removes and returns the last item in the list. (The square bracketsaround the i in the method signature denote that the parameter is optional, not that youshould type square brackets at that position. You will see this notation frequently in the Python Library Reference.)
#
# $\bullet$ list.clear() Remove all items from the list. Equivalent to del a[:].
#
# $\bullet$ list.index(x[, start[, end]]) Return zero-based index in the list of the first item whose value is equal to x. Raises a ValueError if there is no such item.
#
# The optional arguments start and end are interpreted as in the slice notation and are usedto limit the search to a particular subsequence of the list. The returned index is computed relative to the beginning of the full sequence rather than the start argument.
#
# $\bullet$ list.count(x) Return the number of times x appears in the list.
#
# $\bullet$ list.sort(*, key=None, reverse=False) Sort the items of the list in place (the arguments can be used for sort customization, see sorted() for their explanation).
#
# $\bullet$ list.reverse() Reverse the elements of the list in place.
#
# $\bullet$ list.copy() Return a shallow copy of the list. Equivalent to a[:].
#
#  An example that uses most of the list methods:

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana', 'apple','banana']
fruits.count('apple')
# Out:
# 3

# %%
fruits.count('Tomato')
# Out:
# 0

# %%
fruits.index('banana')
# Out:
# 3

# %%
fruits.index('banana', 4)  # Find next banana starting at position 4
# Out:
# 6

# %%
fruits.reverse()
fruits
# Out:
# ['banana',
#  'apple',
#  'banana',
#  'apple',
#  'kiwi',
#  'banana',
#  'pear',
#  'apple',
#  'orange']

# %%
fruits.append('grape')
fruits
# Out:
# ['banana',
#  'apple',
#  'banana',
#  'apple',
#  'kiwi',
#  'banana',
#  'pear',
#  'apple',
#  'orange',
#  'grape']

# %%
fruits.sort()
fruits
# Out:
# ['apple',
#  'apple',
#  'apple',
#  'banana',
#  'banana',
#  'banana',
#  'grape',
#  'kiwi',
#  'orange',
#  'pear']

# %%
fruits.pop(2)
fruits
# Out:
# ['apple',
#  'apple',
#  'banana',
#  'banana',
#  'banana',
#  'grape',
#  'kiwi',
#  'orange',
#  'pear']

# %%
fruits.pop()
fruits
# Out:
# ['apple', 'apple', 'banana', 'banana', 'banana', 'grape', 'kiwi', 'orange']

# %% [markdown]
# Tuple
# Similar to a list, a Python tuple is a collection of Python objects; however, once a tuple is generated, its elements cannot be added or withdrawn. A Tuple can have different kinds of elements, much like a List.

# %%
 # Creating a Tuple with the use of Strings
Tuple0 = ('We', 'are','learning','Python')
print("\nTuple with the use of String: ")
print(Tuple0)
# Out:
# Tuple with the use of String:
# ('We', 'are', 'learning', 'Python')

# %%
 # Creating a Tuple with the use of integers
Tuple1 = (1,2,3,5)
print("\nTuple with the use of integers: ")
print(Tuple1)
# Out:
# Tuple with the use of integers:
# (1, 2, 3, 5)

# %%
# Creating a Tuple with the use of list
List_1 = [2, 1, 7, 0, 66, 8888, 0.5]
print(List_1)
print("\nTuple using List: ")
Tuple = tuple(List_1)
print(Tuple)
# Out:
# [2, 1, 7, 0, 66, 8888, 0.5]
#
# Tuple using List:
# (2, 1, 7, 0, 66, 8888, 0.5)

# %%
# Accessing element using indexing
print("First element of tuple")
print(Tuple[0])
# Accessing element from second last using negative indexing
print("\nSecond last element of tuple")
print(Tuple[-2])
print("\nLast element of tuple")
print(Tuple[-1])
# Out:
# First element of tuple
# 2
#
# Second last element of tuple
# 8888
#
# Last element of tuple
# 0.5
