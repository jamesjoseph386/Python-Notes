# %% [markdown]
# ### Exercise:
# 1. Write a program to check whether the given matrix is symmetric or skew symmetric.
# 2. Write a program to express the given matrix as the sum of a symmetric matrix and a skew symmetric matrix.
# 3. Write a program to define a 4X4 matrix and perform the following manipulations- <br> (i) Find the square root of each element in the 3rd row <br> (ii) Add the corresponding elements of first and second columns <br> (iii) Extract the first column of the matrix and reshape it into a 2X2 matrix.
# 4. Write a program to define a 5X5 matrix and perform the following- <br> (i) Find the sum of all the elements in the matrix <br> (ii) Find the product of all the elements in the matrix <br> (iii) Find the trace of the matrix <br> (iv) Find the minimum value in the matrix <br> (v) Find the maximum value in the matrix <br> (vi) Sort the elements in each row of the matrix.
