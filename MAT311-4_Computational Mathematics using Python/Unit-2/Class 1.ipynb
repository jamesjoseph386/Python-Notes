# %% [markdown]
# # File Handling
# Read and write files using Python.

# %%
with open("example.txt", "w") as file:  #Writing
    file.write("Hello, World! \n Welcome to python programming")

with open("example.txt", "r") as file:  #Reading 
    content = file.read()
    print("File content:", content)
# Out:
# File content: Hello, World!
#  Welcome to python programming

# %% [markdown]
# # Create a DataFrame

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)
print("DataFrame:\n", df)
# Out:
# DataFrame:
#        Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# # To Access a specific columns

# %%
print("\nNames:\n", df['Name'])
# Out:
# Names:
#  0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %% [markdown]
# # To Filter rows

# %%
print("\nPeople older than 30:\n", df[df['Age'] > 30])
# Out:
# People older than 30:
#        Name  Age     City
# 2  Charlie   35  Chicago

# %% [markdown]
# # Selecting a specific column

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %% [markdown]
# # Selecting multiple columns

# %%
df[['Name', 'Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# # Selecting a specific row using loc

# %%
df.loc[1]
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object

# %%
df.loc[2]
# Out:
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %% [markdown]
# # Selecting a row using iloc

# %%
df.iloc[1]
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object

# %%
df.iloc[2]
# Out:
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
df = pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie','Sam'],
        'Age': [25, 30, 35, 28],
        'City': ['New York', 'Los Angeles', 'Chicago', 'Alaska']
}, index=['a', 'b', 'c', 'd'])
print(df)
# Selecting the first two rows
print("\n",df.loc['a':'b'])   # Returns rows 'a' and 'b' (Both included)
print("\n",df.iloc[0:2])      # Returns rows at index 0 and 1 (2 is excluded)

# Selecting a specific value
print("\n",df.loc['c', 'City']) # Returns 'Chicago'
print("\n",df.iloc[2, 2])       # Returns 'Chicago'
# Out:
#       Name  Age         City
# a    Alice   25     New York
# b      Bob   30  Los Angeles
# c  Charlie   35      Chicago
# d      Sam   28       Alaska
#
#      Name  Age         City
# a  Alice   25     New York
# b    Bob   30  Los Angeles
#
#      Name  Age         City
# a  Alice   25     New York
# b    Bob   30  Los Angeles
#
#  Chicago
#
#  Chicago

# %% [markdown]
# # Data frame to CSV

# %%
import pandas as pd
data_dict = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'Salary': [50000, 55000, 60000, 65000, 70000]
}

df = pd.DataFrame(data_dict)
df.to_csv('data.csv', index=False)  
print("See the CSV file in the folder")
# Out:
# CSV file written successfully.

# %% [markdown]
# # Reading data from the CSV file

# %%
df_csv = pd.read_csv('data.csv') #we can read our own CSV file too
print("\nData read from CSV file:")
print(df_csv)
# Out:
# Data read from CSV file:
#       Name  Age  Salary
# 0    Alice   24   50000
# 1      Bob   27   55000
# 2  Charlie   22   60000
# 3    David   32   65000
# 4      Eva   29   70000

# %% [markdown]
# # data to Excel file

# %%
df.to_excel('data.xlsx', index=False, sheet_name='Sheet1')  # Writing to Excel
print("\nExcel file written successfully.")
# Out:
# Excel file written successfully.

# %% [markdown]
# # Reading data from the Excel file

# %%
df_excel = pd.read_excel('data.xlsx', sheet_name='Sheet1')
print("\nData read from Excel file:")
print(df_excel)
# Out:
# Data read from Excel file:
#       Name  Age  Salary
# 0    Alice   24   50000
# 1      Bob   27   55000
# 2  Charlie   22   60000
# 3    David   32   65000
# 4      Eva   29   70000

# %% [markdown]
# # Mean of Age and Salary

# %%
df[['Age', 'Salary']].mean()
# Out:
# Age          26.8
# Salary    60000.0
# dtype: float64

# %% [markdown]
# # Median of Age and Salary

# %%
print("\nMedian of Age and Salary:")
print(df[['Age', 'Salary']].median())
# Out:
# Median of Age and Salary:
# Age          27.0
# Salary    60000.0
# dtype: float64

# %% [markdown]
# # Mode of Age and Salary

# %%
print("\nMode of Age and Salary:")
print(df[['Age', 'Salary']].mode())
# Out:
# Mode of Age and Salary:
#    Age  Salary
# 0   22   50000
# 1   24   55000
# 2   27   60000
# 3   29   65000
# 4   32   70000

# %% [markdown]
# # Summarize the data

# %%
print("\nSummary Statistics:\n", df.describe())
# Out:
# Summary Statistics:
#          Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %% [markdown]
# Seaborn is a visualization library for statistical graphics plotting in Python.
#
# Key Features:
#
# Simplifies complex visualizations like heatmaps, violin plots, and pair plots.
#
# Supports statistical functions (e.g., regression plots).
#
# Works efficiently with Pandas for easy data handling.
#
# Provides built-in datasets for practice (e.g., tips, titanic, iris).

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\johnk\anaconda\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\johnk\anaconda\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\johnk\anaconda\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\johnk\anaconda\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\johnk\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\johnk\anaconda\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\johnk\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Creating a bar plot for a Sample dataset using Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


data = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Values': [10, 20, 15, 25, 30]
})


sns.barplot(x='Category', y='Values', data=data)
plt.title("Seaborn Bar Plot")
plt.show()

# %% [markdown]
# # Seaborn comes with several built-in datasets that you can use for practice and testing. These datasets are included with the library and can be loaded using sns.load_dataset().

# %%
import seaborn as sns

print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# # Loading dataset from seaborn
#
# Syntax: sns.load_dataset("name of the dataset")

# %%
df = sns.load_dataset("tips")  
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=df)
plt.title('Scatter Plot with Seaborn')
plt.show()

# %% [markdown]
# # Dataset information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
