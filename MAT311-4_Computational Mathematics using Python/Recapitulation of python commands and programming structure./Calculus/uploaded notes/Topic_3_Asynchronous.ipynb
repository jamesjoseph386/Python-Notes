# %% [markdown]
# 1.Derive the expression for determining displacement s occured for a body over a time period t with constant velocity v and  constant acceleration a started with an initial speed u, and an initial position of zero.

# %% [markdown]
# 2.Determine the value of following functions
#
#   a. $log_10 2$
#
#   b. tan (0)
#
#   c. $\sqrt{121}$

# %% [markdown]
# 3.Solve $lim_{x→2}(8−3x+12x^2)$

# %% [markdown]
#   4.Derive the expression for determining hypotenuse of aright angled triangle (Pythagoras Theorem)

# %% [markdown]
# 5.Determine the limit of following
#
# a. $f(x) = 1 + 1/x$ at x =4
#
# b. $\frac{sinx}{x}$ at x=0

# %% [markdown]
# 6.f(x) = sin $\frac{x}{2}$
#
#   g(x) = $log x$
#
#        Determine
#
#        1. f+g
#
#        2. f-g
#
#        3. fg
#
#        4. f/g
#
#        5. f composition g
#
#        6. g composition f
#
#        at x=1
