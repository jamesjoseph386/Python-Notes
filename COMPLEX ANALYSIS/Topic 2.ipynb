# %%
from datetime import date
today=date.today()
print("Today's date:",today)
# Out:
# Today's date: 2021-01-28

# %% [markdown]
# # Python functions in complex numbers

# %% [markdown]
# ## 'cmath’ module
#
# The 'cmath’ module defines functions that take a complex number as argument and return a complex number as result.

# %%
# importing "cmath" for complex number operations
from cmath import *
from math import *

# %% [markdown]
# ## Polar and rectangular form of the complex number

# %% [markdown]
# 1). The Polar form of a complex number is another way to represent a complex number.<br>
# 2). The form $z=a+bi$ is called the rectangular coordinate form of a complex number.<br><br>
#
# #### The polar form of a complex number $z=a+bi$ is $z=r(cosθ+isinθ)$ , where $r=|z|=\sqrt{a^2+b^2}$ , $a=r~cos~θ$  and $ b=r~sin~θ$.

# %% [markdown]
# ##### Q. Find the polar and rectangular form of the complex number

# %%
z7=8-5j
print("The complex no. is", z7)
print("")
# converting complex number into polar using polar()
a1=polar(z7)
print("Polar form is:", a1)
print("")
# converting complex number into rectangular using rect()
a2=rect(a1[0],a1[1])
print("Rectangular form is:", a2)
# Out:
# The complex no. is (8-5j)
#
# Polar form is: (9.433981132056603, -0.5585993153435624)
#
# Rectangular form is: (8-4.999999999999999j)

# %% [markdown]
# ## Absolute value of a complex number

# %% [markdown]
# The absolute value (or modulus or magnitude) of a complex number $ z = x + y j$ is $ r=|z|={\sqrt {x^{2}+y^{2}}}$. If z is a real number (that is, if $y = 0$), then $r = |x|$. That is, the absolute value of a real number equals its absolute value as a complex number.

# %%
from math import *
from cmath import *
from numpy import *
z=complex(5,8)
print(" The absolute value or modulus or magnitude of a complex number",z," is",abs(z))
# Out:
#  The absolute value or modulus or magnitude of a complex number (5+8j)  is 9.433981132056603

# %% [markdown]
# ## Argument of a complex number

# %% [markdown]
# The argument of a complex number is defined as the angle inclined from the real axis in the direction of the complex number represented on the complex plane. It is denoted by $\theta$ or $\phi$. It is measured in the standard unit called “radians”.
#
# In polar form, a complex number is represented by the equation $r(cos \theta + i$ $sin \theta)$, where, $\theta$ is the argument. The argument function is denoted by $arg(z)$, where $z$ denotes the complex number, i.e. $z = x + iy$. The computation of the complex argument can be done by using the following formula:
#
# $arg (z) = arg (x+iy) = tan^{-1}(y/x)$
#
# Therefore, the argument $\theta$ is represented as:
#
# $\theta = tan^{-1} (y/x)$
#
# Note that, in Python, the argument is obtained using the function "phase()" in the library cmath.

# %%
import math
import cmath
z1=complex(3,5)
print("Argument of the complex number", z1," using in built command is",phase(z)) #inbuilt co
print("Argument of the complex number", z1," without using in built command is",atan(z.imag/z.real))
# Out:
# Argument of the complex number (3+5j)  using in built command is 1.5263811115479857
# Argument of the complex number (3+5j)  without using in built command is (1.5263811115479857+0j)

# %% [markdown]
# ## Verification of Euler's Formula

# %% [markdown]
# Euler's formula, named after Leonhard Euler, is a mathematical formula in complex analysis that establishes the fundamental relationship between the trigonometric functions and the complex exponential function. Euler's formula states that for any real number $x$:
#
# $ e^{ix}=\cos x+i\sin x$,
#
# where $e$ is the base of the natural logarithm, $i$ is the imaginary unit, and cos and sin are the trigonometric functions cosine and sine respectively.

# %%
z=complex(90,4)
print("The complex number is",z)
s=cmath.exp(z)
print("LHS= e^z=",s)
d=(cmath.exp(z.real))*(cmath.cos(z.imag)+1j*cmath.sin(z.imag))
print("RHS= ",d)
if(d==s):
    print("Eulers Law verified")
else:
    print("Eulers Law not verified")
# Out:
# The complex number is (90+4j)
# LHS= e^z= (-7.977088282117938e+38-9.236042584217578e+38j)
# RHS=  (-7.977088282117938e+38-9.236042584217578e+38j)
# Eulers Law verified

# %% [markdown]
# ## Plotting the roots of Unity

# %% [markdown]
# ### Cube root

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
x=Symbol('x')
s=x**3-1
t=solve(s)
print(t)
for i in range(len(t)):
    z=complex(t[i])
    plt.scatter(z.real,z.imag)
    plt.text(z.real,z.imag,z)
    plt.show
# Out:
# [1, -1/2 - sqrt(3)*I/2, -1/2 + sqrt(3)*I/2]

# %% [markdown]
# ## Fourth root of unity

# %%
y=Symbol('y')
r=y**4-1
q=solve(r)
print(q)
for i in range(len(q)):
    a=complex(q[i])
    plt.scatter(a.real,a.imag)
    plt.text(a.real,a.imag,a)
    plt.show
# Out:
# [-1, 1, -I, I]

# %% [markdown]
# ## General Code

# %%
n=int(input("Enter the number of root to be solved: "))
w=Symbol('w')
v=w**n-1
e=solve(v)
print(e)
for i in range(len(e)):
    b=complex(e[i])
    plt.scatter(b.real,b.imag)
    plt.text(b.real,b.imag,b)
    plt.show
# Out:
# Enter the number of root to be solved: 6
# [-1, 1, -1/2 - sqrt(3)*I/2, -1/2 + sqrt(3)*I/2, 1/2 - sqrt(3)*I/2, 1/2 + sqrt(3)*I/2]

# %% [markdown]
# ## Plotting the given set of complex numbers

# %%
n=int(input("Enter the number of points to be plotted: "))
x=[]
y=[]
for i in range(0,n):
    re=float(input("Enter the real part : "))
    ig=float(input("Enter the imaginay part : "))
    x.append(re)
    y.append(ig)
plt.scatter(x,y,marker='*',color='green')
for j in range(len(x)):
    plt.text(x[j],y[j],x[j]+1j*y[j]) #Try giving "j" instead of "1j" and see what is the difference in output.
    plt.xlabel("Real Axis -->")
    plt.ylabel("Imaginary Axis -->")
    plt.suptitle("Plotting the given numbers of complex numbers")
plt.show()
# Out:
# Enter the number of points to be plotted: 3
# Enter the real part : 1
# Enter the imaginay part : 2
# Enter the real part : 3
# Enter the imaginay part : 4
# Enter the real part : 5
# Enter the imaginay part : 6

# %% [markdown]
# ### Q. Out of the three points, $z_1= 2.5 +1.9$ $j$, $z_2= 1.5-2.9$ $j$ and $z_3= -2+2.2$ $j$, find the point which is farthest away from the origin.

# %%
z1 = complex(2.5,1.9)
z2 = complex(1.5,2.9)
z3 = complex(-2,2.2)
w1 = abs(z1)
w2 = abs(z3)
w3 = abs(z3)
c = max(w1,w2,w3)
if c == w1:
    print("z1=",z1," is farthest away from origin")
elif c == w2:
    print("z2=",z2," is farthest away from origin")
elif c== w3:
    print("z3=",z3," is farhtest away from origin")
print("The distance from the origin is: ", c)
# Out:
# z1= (2.5+1.9j)  is farthest away from origin
# The distance from the origin is:  3.1400636936215163

# %% [markdown]
# ### Q. If $𝑎 + 𝑖𝑏 = \frac{3-i}{2+3i}+ \frac{2-2i}{1-5i}$ , find $a$ and $b$.

# %%
z = complex(3,-1)/complex(2,3) + complex(2,-2)/complex(1,-5)
a = z.real
b = z.imag
print("The value of a: ",a)
print()
print("The value of b: ",b)
# Out:
# The value of a:  0.6923076923076923
#
# The value of b:  -0.5384615384615384
