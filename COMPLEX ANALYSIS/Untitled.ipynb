# %% [markdown]
# # Introduction to Complex Numbers

# %%
from datetime import date
today=date.today()
print("Today's date:",today)
# Out:
# Today's date: 2025-01-27

# %% [markdown]
# ## 1)Defining Complex Number

# %%
x=5+3j # In Python, the letter 'j' denotes the imaginary unit.
x
# Out:
# (5+3j)

# %%
y=2j+4
y
# Out:
# (4+2j)

# %%
p=3
q=5
r=p+j*q
r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 p=3
#       2 q=5
# ----> 3 r=p+j*q
#       4 r
#
# NameError: name 'j' is not defined
