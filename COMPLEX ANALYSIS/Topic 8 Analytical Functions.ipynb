# %%
from datetime import date
today=date.today()
print("Today's date:",today)
# Out:
# Today's date: 2021-02-19

# %% [markdown]
# # Analytical Functions

# %% [markdown]
# A function f(z) is analytic if it has a complex derivative f'(z). A function f(z) is said to be analytic in a region R of the complex plane if f(z) has a derivative at each point of R and if f(z) is single valued.

# %% [markdown]
# Check if f(z)=2xy+2xi is analytic.

# %%
from cmath import *
from math import *
x,y,i=symbols("x, y, i")
u=2*x*y
v=2*x
print("Given expression f(z):",u,"+I",v)
diff_ux=diff(u,x,1)
print("\n Derivative of u wrt x:", diff_ux)
diff_uy=diff(u,y,1)
print("\n Derivative of u wrt y:", diff_uy)
diff_vx=diff(v,x,1)
print("\n Derivative of v wrt x:", diff_vx)
diff_vy=diff(v,y,1)
print("\n Derivative of v wrt y:", diff_vy)
if(diff_ux==diff_vy and diff_uy==-diff_vx):
    print("\n f(z) is an analytical function.")
else:
    print("\n f(z) is not an analytical function.")
# Out:
# Given expression f(z): 2*x*y +I 2*x
#
#  Derivative of u wrt x: 2*y
#
#  Derivative of u wrt y: 2*x
#
#  Derivative of v wrt x: 2
#
#  Derivative of v wrt y: 0
#
#  f(z) is not an analytical function.

# %% [markdown]
# To verify if the given complex function f(z) is analytic or not.

# %%
from sympy import *
import cmath
u,v,x,y,i=symbols("u, v, x, y, i")
u=input("Enter u:")
v=input("Enter v:")
print("Given expression f(z):",u,"+I",v)
diff_ux=diff(u,x,1)
print("\n Derivative of u wrt x:", diff_ux)
diff_uy=diff(u,y,1)
print("\n Derivative of u wrt y:", diff_uy)
diff_vx=diff(v,x,1)
print("\n Derivative of v wrt x:", diff_vx)
diff_vy=diff(v,y,1)
print("\n Derivative of v wrt y:", diff_vy)
if(diff_ux==diff_vy and diff_uy==-diff_vx):
    print("\n f(z) is an analytical function.")
else:
    print("\n f(z) is not an analytical function.")
# Out:
# Enter u:x**2+1
# Enter v:x+1
# Given expression f(z): x**2+1 +I x+1
#
#  Derivative of u wrt x: 2*x
#
#  Derivative of u wrt y: 0
#
#  Derivative of v wrt x: 1
#
#  Derivative of v wrt y: 0
#
#  f(z) is not an analytical function.

# %% [markdown]
# Problems:

# %% [markdown]
# Check if the following functions is analytic or not: $f(z)=\dfrac{(x-iy)}{(x^2+y^2)} $

# %% [markdown]
# Check if $f(z)= z^3 $ is analytic or not.

# %% [markdown]
# Check if $f(z)= e^x(x cos y - y sin y + cos y) $ is analytic or not.

# %% [markdown]
# Check if the following functions is analytic or not: $f(z)= 2x + ixy^2 $

# %% [markdown]
# Check if the following functions is analytic or not: $f(z)= xy +iy$
