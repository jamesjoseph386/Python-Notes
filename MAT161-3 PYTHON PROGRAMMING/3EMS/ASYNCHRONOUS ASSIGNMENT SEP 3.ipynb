# %% [markdown]
# Q.No. 1: Find A$^3$ - 3A + 20I for any A of order 4 and hence, find the inverse of A.</b>

# %% [markdown]
# <b> Q.No2: Write a program to check whether the given matrix is symmetric or skew symmetric.<br><br>
# (i)$$\begin{bmatrix} 1 & 2 & 3 \\ 2 & 5 & 6 \\ 3 & 6 & 9\end{bmatrix}$$
# </b>

# %% [markdown]
# <b>Q3: Write a program to define a 4X4 matrix and perform the following manupulations-
# $$\begin{bmatrix} 2 & 3 & 4 & 5 \\ 8 & 10 & 20 & 1 \\ 6 & 10 & 21 & 20 \\ 7 & 5 & 2 & 0\end{bmatrix}$$
# </b>
# (i) Find the square root of each element in the 3rd row.<br>
# (ii) Add the corresponding elements of the first and second columns.<br>
# (iii) Extract the first column of the matrix and reshape it into a 2X2 matrix.
