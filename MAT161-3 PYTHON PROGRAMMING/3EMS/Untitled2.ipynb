# %%
import numpy as np
M=np.array([[1,-2,3],[2,1,-6],[-3,6,1]])
I=np.array([1,0,0],[0,1,0],[0,0,1])
int c
Z=np.solve(det(A-cI)=0)
# Out:
#   Cell In[1], line 4
#     int c
#         ^
# SyntaxError: invalid syntax
