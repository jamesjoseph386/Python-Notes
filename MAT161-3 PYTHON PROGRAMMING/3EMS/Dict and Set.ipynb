# %% [markdown]
# ### An Introduction to Dictionary in Python:
#
# #### $\bullet$ Dictionaries are used to store data values in key:value pairs. (unordered, mutable, key values should be unique)
# #### $\bullet$ Dictionaries are written with curly brackets, and have keys and values:
#
# Syntax: dictionary = {key: value, key : value , ... ,key: value}
#
# #### Dictionary Items:
#
# #### $\bullet$ Dictionary items are presented in key:value pairs, and can be referred to by using the key name.
# #### $\bullet$ The values in dictionary items can be of any data type.

# %%
#Create and print a dictionary:
person = {
    'first_name': 'John',
    'last_name': 'Doe',
    'age': 25,
    'favorite_colors': ['blue', 'green']}
print("Details of that Person:\n",person)
# Out:
# Details of that Person:
#  {'first_name': 'John', 'last_name': 'Doe', 'age': 25, 'favorite_colors': ['blue', 'green']}

# %%
person = {'first_name': 'John', 'last_name': 'Doe', 'age': 25, 'favorite_colors': ['blue', 'green']}
print(person2.keys())
print(person2.values()) 
print(person.items())
print(person['favorite colors'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 person = {'first_name': 'John', 'last_name': 'Doe', 'age': 25, 'favorite_colors': ['blue', 'green']}
# ----> 2 print(person2.keys())
#       3 print(person2.values())
#       4 print(person.items())
#
# NameError: name 'person2' is not defined

# %%
person2 = {"name": "Jessa", "country": "USA", "telephone": 1178}
print(person2)
# Out:
# {'name': 'Jessa', 'country': 'USA', 'telephone': 1178}

# %%
print(type(person2))
# Out:
# <class 'dict'>

# %%
emptydict = {}
print(emptydict)
# Out:
# {}

# %%
print(type(emptydict))
# Out:
# <class 'dict'>

# %%
print(person2.keys()) ## keys()- Returns the list of all keys present in the dictionary.
# Out:
# dict_keys(['name', 'country', 'telephone'])

# %%
print(person2.values()) ### values() - Returns the list of all values present in the dictionary
# Out:
# dict_values(['Jessa', 'USA', 1178])

# %%
#items()-Returns all the items present in the dictionary.
#Each item will be inside a tuple as a key-value pair.
print(person.items())
# Out:
# dict_items([('first_name', 'John'), ('last_name', 'Doe'), ('age', 25), ('favorite_colors', ['blue', 'green'])])

# %% [markdown]
# #### Accessing values in a Dictionary:
# ##### To access a value by key from a dictionary, place the key inside square brackets: dict[key]

# %%
print(person['first_name'])
# Out:
# John

# %%
print(person['favorite_colors'])
# Out:
# ['blue', 'green']

# %%
print(person.get('last_name')) #### by using get()
# Out:
# Doe

# %% [markdown]
# ### get() - If the key doesn’t exist, the get() method returns None instead of giving a KeyError.

# %%
### for instance
print(person['middle name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 ### for instance
# ----> 2 print(person['middle name'])
#
# KeyError: 'middle name'

# %%
print(person.get('middle name'))
# Out:
# None

# %% [markdown]
# ### The get() method also returns a default value when the key doesn’t exist by passing the default value to its second argument.

# %%
print(person.get('middle name', 'does not exsits'))
# Out:
# does not exsits

# %%
person = {'first_name': 'John', 'last_name': 'Doe', 'age': 25, 'favorite_colors': ['blue', 'green']}
print(person.keys())
print(person.values()) 
print(person.items())
print(person['middle name'])
# Out:
# dict_keys(['first_name', 'last_name', 'age', 'favorite_colors'])
# dict_values(['John', 'Doe', 25, ['blue', 'green']])
# dict_items([('first_name', 'John'), ('last_name', 'Doe'), ('age', 25), ('favorite_colors', ['blue', 'green'])])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       3 print(person.values())
#       4 print(person.items())
# ----> 5 print(person['middle name'])
#
# KeyError: 'middle name'

# %% [markdown]
# ### Adding new key-value pairs

# %%
person['gender'] = 'male'
print("The updated dictionary is: \n", person)
# Out:
# The updated dictionary is:
#  {'first_name': 'John', 'last_name': 'Doe', 'age': 25, 'favorite_colors': ['blue', 'green'], 'gender': 'male'}

# %%
## We can also add more than one key using the update() method.

# %%
person.update({'weight': 50, 'height': 6})
print("The updated dictionary is: \n", person)
# Out:
# The updated dictionary is:
#  {'first_name': 'John', 'last_name': 'Doe', 'age': 25, 'favorite_colors': ['blue', 'green'], 'gender': 'male', 'weight': 50, 'height': 6}

# %% [markdown]
# ### Modifying values in a key-value pair : Syntax: dict[key] = new_value

# %%
person['age']=26
print("The updated dictionary is: \n", person)
# Out:
# The updated dictionary is:
#  {'first_name': 'John', 'last_name': 'Doe', 'age': 26, 'favorite_colors': ['blue', 'green'], 'active': True}

# %% [markdown]
# #### To remove a key-value pair by a key, you use the del statement: del dict[key]

# %%
del person['active']
print(person)
# Out:
# {'first_name': 'John', 'last_name': 'Doe', 'age': 26, 'favorite_colors': ['blue', 'green']}

# %% [markdown]
# # SETS IN PYTHON

# %%
sample_set = {'Mark', 'Jessa', 25,25, 25, 75.25, 'Jessa'}
print(sample_set)
# Out:
# {25, 75.25, 'Mark', 'Jessa'}

# %%
book_set = set(("Harry Potter", "Angels and Demons", "Atlas Shrugged"))
print(book_set)
# Out:
# {'Atlas Shrugged', 'Harry Potter', 'Angels and Demons'}

# %%
print(type(book_set))
# Out:
# <class 'set'>

# %%
example = {} ###it will create an empty dict
print(type(example))
# Out:
# <class 'dict'>

# %%
## TO create an empty set use set()
emty_set = set()
print(type(emty_set)) 
# class 'set'
# Out:
# <class 'set'>

# %% [markdown]
# ### Create a set from a list

# %%
number_list = [20, 30, 20, 30, 50, 30,10,50]
# create a set from a list
sample_set2 = set(number_list)
print(sample_set2)
# Out:
# {50, 10, 20, 30}

# %%
## The items of the set are unordered and they don’t have any index number.
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
for i in book_set:
    print(i)
# Out:
# Harry Potter
# Angels and Demons
# Atlas Shrugged

# %% [markdown]
# ### The $in$ operator checks whether the item is present in the set,
# ### and returns True if it present otherwise, it will return False.

# %%
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
if 'Harry Potter' in book_set:
    print("Book exists in the book set")
else:
    print("Book doesn't exist in the book set")
# Out:
# Book exists in the book set

# %%
# check another item which is not present inside a set
print("A Man called Ove" in book_set)
# Out:
# False

# %%
print(len(book_set))
# Out:
# 3

# %% [markdown]
# ### We can add new items to the set using the following two ways.

# %%
book_set = {'Harry Potter', 'Angels and Demons'}
# add() method
book_set.add('The God of Small Things')
# display the updated set
print(book_set)
# Out:
# {'Harry Potter', 'The God of Small Things', 'Angels and Demons'}

# %%
# update() method to add more than one item
book_set.update(['Atlas Shrugged', 'Ulysses'])
# display the updated set
print(book_set)
# Out:
# {'Harry Potter', 'Ulysses', 'Atlas Shrugged', 'The God of Small Things', 'Angels and Demons'}

# %%
color_set = {'red', 'orange', 'yellow', 'white', 'black'}
# remove single item
color_set.remove('yellow')
print(color_set)
# Out:
# {'black', 'orange', 'white', 'red'}

# %%
# remove all items
color_set.clear()
print(color_set)
# Out:
# set()

# %% [markdown]
# ### Set Operations

# %% [markdown]
# Union -> | or union()
#
# Intersection -> & or intersection()
#
# Difference -> -	or difference()
#
# Symmetric Difference -> ^ or symmetric_difference()

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}

# union of two set using OR operator
new_color_set = color_set | remaining_colors
print("The union of two sets:",new_color_set)


# union using union() method
new_colors = color_set.union(remaining_colors)
print("The union of two sets:",new_colors)
# Out:
# The union of two sets: {'green', 'red', 'indigo', 'yellow', 'blue', 'orange', 'violet'}
# The union of two sets: {'green', 'red', 'indigo', 'yellow', 'blue', 'orange', 'violet'}

# %%
new_color_set = color_set & remaining_colors
print("The intersection of two sets:",new_color_set)
# Out:
# The intersection of two sets: {'indigo'}

# %%
new_color_set = color_set - remaining_colors
print("The difference:",new_color_set)
# Out:
# The difference: {'green', 'yellow', 'blue', 'violet'}

# %%
# symmetric difference
unique_items = color_set ^ remaining_colors
print("The symmetric difference:",unique_items)
# Out:
# The symmetric difference: {'red', 'yellow', 'blue', 'orange', 'violet', 'green'}

# %% [markdown]
# ### Subset and Superset
# Syntax: issubset()   and  issuperset()

# %%
Set1={1,2,3,4,5}
Set2={2,3,4}
print(Set2.issubset(Set1))
# Out:
# True

# %%
Set1={1,2,(1,3),4,5}
Set2={2,3,4}
print(Set1.issuperset(Set2))
print(Set2.issubset(Set1))
# Out:
# False
# False

# %%
Set1.isdisjoint(Set2)
# Out:
# False

# %% [markdown]
# ## Frozen Set
# doesn’t allow adding or removing items from a set.

# %%
rainbow = ('violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red')
# create a frozenset
f_set = frozenset(rainbow)

print(f_set)
print(type(f_set))
# Out:
# frozenset({'orange', 'indigo', 'red', 'green', 'violet', 'blue', 'yellow'})
# <class 'frozenset'>

# %%
f_set.update('pink')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f_set.update('pink')
#
# AttributeError: 'frozenset' object has no attribute 'update'

# %%
set1={(1,2),(2,3),(3,4)}
set2={(1,2),(2,3),(4,4)}
print(set1&set2)
# Out:
# {(2, 3), (1, 2)}

# %%
x=input()
f=x.split("J")
print(f)
print(set(f))
# Out:
#  my name is James Joseph
# ['my name is ', 'ames ', 'oseph']
# {'ames ', 'oseph', 'my name is '}

# %%
a=eval(input('Enter the first list:'))
b=eval(input('Enter the first list:'))
c=[]

if len(a)==len(b):
    for i in range(0,min(len(a),len(b))):
        x=(a[i],b[i])
        c.append(x) 
    print(c)

elif len(a)>len(b):
    for i in range(min(len(a),len(b)),max(len(a),len(b))):
        x=(a[i],None)
        c.append(x) 
    print(c)
    
else:
    for i in range(min(len(a),len(b)),max(len(a),len(b))):
        x=(None,b[i])
        c.append(x) 
    print(c)
# Out:
# Enter the first list:[1,2,3]
# Enter the first list:[2,3,4,5]
# [(None, 5)]
