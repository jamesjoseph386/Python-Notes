# %% [markdown]
# Q. Examine the consistency of the following system of equations and solve if consistent<br>
# 1) $x_1 + 2x_2 = 3$<br>
#    $2x_1 + x_2 = 2$<br>
#    $3x_1 + 3x_2 = 1$
#
# 2) $x_1 + 2x_2 + x_3 + 4x_4 = 3$<br>
#    $2x_1 - x_2 + 7x_3 + 5x_4 = 2$<br>
#    $3x_1 + 3x_2 - x_3 + x_4 = -8$
#
#
# 3) $-x_1 + 6x_2 - x_3 - x_4 = -9$<br>
#    $2x_1 - x_2 + 7x_3 + 5x_4 = 2$<br>
#    $x_1 + x_2 + x_3 - x_4 = -8$<br>
#    $x_1 + x_2 - x_3 + 7x_4 = 0$

# %% [markdown]
# <b> Q. Find the eigen values and eigen vectors of the following matrices </b>
#
# 1) $B = \begin{bmatrix}1 & 1 & 1 \\ 3 & 1 & -2 \\2 & 4 & 7\end{bmatrix}$</b>
# 2) $A = \begin{bmatrix}1 & 2 & 3\\ 2 & 1 & 4\\3 & 0 & 5\end{bmatrix}$
# 3) $A = \begin{bmatrix}1 & 7 & 5 & 6 \\ 7 & 2 & 6 & 7 \\-1 & -3 &-3 & 4\end{bmatrix}$
