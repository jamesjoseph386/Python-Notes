# %%
s1=eval(input("Enter set one:",))
s2=eval(input("Enter set one:",))
l=[]
for i in s1:
    if i in s2:
        l.append(i)

print(set(l))
# Out:
# Enter set one:{(1,2),(1,3),(1,4)}
# Enter set one:{(1,2),(1,3),(4,1)}
# {(1, 2), (1, 3)}
