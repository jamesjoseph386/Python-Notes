# %%
import pandas as pd
data = pd.read_excel("Student.xlsx")
data1 = data.loc[data["Marks obtained in semester "] > 90,]
data2 = data1.loc[data1["Year of passing "] == 2021]
data2
# Out:
#   Student name   Year of passing   Marks obtained in semester
# 1         Karan              2021                           93
# 4         Kedar              2021                           96

# %%
L=eval(input("Enter 4 tuples:"))
for i in range(0,4):
    T=L[i]
    print(T)
    for j in range(i+1,4):
        T1=L[j]
        if(T==T1)
            L.del(i)
print(L)
# Out:
#   File "<ipython-input-40-5d6626437edc>", line 7
#     if(T.is(T1))
#          ^
# SyntaxError: invalid syntax
