# %%
t1=int(input("Enter the tup1:",))
t2=int(input("Enter the tup2:",))
t3=int(input("Enter the tup3:",))
t4=int(input("Enter the tup4:",))
l=[t1,t2,t3,t4]
for i in l:
    if(t1==t2 or t1==t3 or t1==4):
        l.pop(i)
        print(l)
    elif(t2==t1 or t2==t3 or t2==t4):
        l.pop(i)
        print(l)
    elif(t3==t1 or t3==t2 or t3==t4):
        l.pop(i)
        print(l)
    elif(t4==t1 or t4==t3 or t4==t2):
        l.pop(i)
        print(l)
print(l)
# Out:
# Enter the tup1:(1,2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\JAMESJ~1\AppData\Local\Temp/ipykernel_6568/3117859784.py in <module>
# ----> 1 t1=int(input("Enter the tup1:",))
#       2 t2=int(input("Enter the tup2:",))
#       3 t3=int(input("Enter the tup3:",))
#       4 t4=int(input("Enter the tup4:",))
#       5 l=[t1,t2,t3,t4]
#
# ValueError: invalid literal for int() with base 10: '(1,2)'
