# %%
# Out:
# Input number of inputs : 2
# Input name : e
# Input phone number : 3
# Input name : ghj
# Input phone number : 5
# {'e': 3, 'ghj': 5}
# [('e', 3), ('ghj', 5)]

# %%
d = dict()
n = int(input("Input number of inputs : "))
for i in range(n):
    name = input("Input name : ")
    ph = int(input("Input phone number : "))
    d[name] = ph
print(d)
l = list()
for (key) in d:
    l1 = tuple([key, d[key]])
    l.append(l1)
print(l)
# Out:
# Input number of inputs : 5
# Input name : Adi
# Input phone number : 98392847573
# Input name : Dia
# Input phone number : 849495737262
# Input name : Bil
# Input phone number : 92390482773
# Input name : Kat
# Input phone number : 92374756362
# Input name : hiya
# Input phone number : 5837225275
# {'Adi': 98392847573, 'Dia': 849495737262, 'Bil': 92390482773, 'Kat': 92374756362, 'hiya': 5837225275}
# [('Adi', 98392847573), ('Dia', 849495737262), ('Bil', 92390482773), ('Kat', 92374756362), ('hiya', 5837225275)]
