# %%
Name={"Aditya":"9999999999","Rajen":"8888888888","Ahana":"7777777777","Prantika":"6666666666","Agnel":"5555555555"}
print(Name)
l = [(k, v) for k, v in Name.items()]
print(l)
# Out:
# {'Aditya': '9999999999', 'Rajen': '8888888888', 'Ahana': '7777777777', 'Prantika': '6666666666', 'Agnel': '5555555555'}
# [('Aditya', '9999999999'), ('Rajen', '8888888888'), ('Ahana', '7777777777'), ('Prantika', '6666666666'), ('Agnel', '5555555555')]

# %%
print (1)
# Out:
# 1
